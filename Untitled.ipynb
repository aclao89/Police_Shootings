# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 
import missingno as msno
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Extract Transform Load (ETL)

# %%
df = pd.read_csv('Raw_Data/datasets_723010_1257097_fatal-police-shootings-data.csv', index_col = 'id')

df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#    race           city state  signs_of_mental_illness threat_level  \
# id
# 3     A        Shelton    WA                     True       attack
# 4     W          Aloha    OR                    False       attack
# 5     H        Wichita    KS                    False        other
# 8     W  San Francisco    CA                     True       attack
# 9     H          Evans    CO                    False       attack
#
#            flee  body_camera
# id
# 3   Not fleeing        False
# 4   Not fleeing        False
# 5   Not fleeing        False
# 8   Not fleeing        False
# 9   Not fleeing        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5416 entries, 0 to 5415
# Data columns (total 14 columns):
# id                         5416 non-null int64
# name                       5416 non-null object
# date                       5416 non-null object
# manner_of_death            5416 non-null object
# armed                      5189 non-null object
# age                        5181 non-null float64
# gender                     5414 non-null object
# race                       4895 non-null object
# city                       5416 non-null object
# state                      5416 non-null object
# signs_of_mental_illness    5416 non-null bool
# threat_level               5416 non-null object
# flee                       5167 non-null object
# body_camera                5416 non-null bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 518.4+ KB

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df

# Given the current climate on police brutality, it's concerning that race has the most null values. 
#This further compounds the fact law enforcement agencies are purposely hiding race to deflate 
#Since each column with null values is less than 10% then we can continue with dropping those rows since it wont impact the analysis too much
# Out:
#                                      column_name  percent_missing
# name                                        name         0.000000
# date                                        date         0.000000
# manner_of_death                  manner_of_death         0.000000
# armed                                      armed         4.191285
# age                                          age         4.338996
# gender                                    gender         0.036928
# race                                        race         9.619645
# city                                        city         0.000000
# state                                      state         0.000000
# signs_of_mental_illness  signs_of_mental_illness         0.000000
# threat_level                        threat_level         0.000000
# flee                                        flee         4.597489
# body_camera                          body_camera         0.000000

# %%
msno.matrix(df)

# %% [markdown]
# # Drop all rows with NaN values

# %%
df_clean = df.dropna(how='any')

df_clean.shape
# Out:
# (4399, 13)

# %% [markdown]
# # Check data types of each column - Time needs to be changed to Datetime

# %%
df_clean.dtypes
# Out:
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# dtype: object

# %%
df_clean['month'] = pd.to_datetime(df_clean['date']).dt.month
df_clean['year'] = pd.to_datetime(df_clean['date']).dt.year
df_clean['day'] = pd.to_datetime(df_clean['date']).dt.day
df_clean
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   name        date   manner_of_death  \
# id
# 3                           Tim Elliot  2015-01-02              shot
# 4                     Lewis Lee Lembke  2015-01-02              shot
# 5                   John Paul Quintero  2015-01-03  shot and Tasered
# 8                      Matthew Hoffman  2015-01-04              shot
# 9                    Michael Rodriguez  2015-01-04              shot
# 11                   Kenneth Joe Brown  2015-01-04              shot
# 13                 Kenneth Arnold Buck  2015-01-05              shot
# 15                       Brock Nichols  2015-01-06              shot
# 16                       Autumn Steele  2015-01-06              shot
# 17                     Leslie Sapp III  2015-01-06              shot
# 19                      Patrick Wetter  2015-01-06  shot and Tasered
# 21                           Ron Sneed  2015-01-07              shot
# 22      Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
#
# 16         unarmed  34.0      F    W         Burlington    IA
# 17      toy weapon  47.0      M    B          Knoxville    PA
# 19           knife  25.0      M    W           Stockton    CA
# 21             gun  31.0      M    B           Freeport    TX
# 22           knife  41.0      M    B           Columbus    OH
# 25             gun  30.0      M    W         Des Moines    IA
# 27             gun  37.0      M    B        New Orleans    LA
# 32          shovel  42.0      M    W     Salt Lake City    UT
# 36         unarmed  36.0      M    B             Strong    AR
# 37             gun  49.0      M    W           Syracuse    UT
# 38             gun  71.0      M    W            England    AR
# 325            gun  33.0      M    H            El Paso    TX
# 42             gun  39.0      M    W             Arcola    IL
# 43             gun  23.0      M    H         South Gate    CA
# 45             gun  29.0      M    H    North Las Vegas    NV
# 46             gun  34.0      M    W        Albuquerque    NM
# 48           knife  43.0      M    W         Jourdanton    TX
# 51             gun  34.0      M    B         Chesapeake    VA
# 52           knife  75.0      M    W         Old Bridge    NJ
# 54             gun  68.0      M    W       Lake Jackson    TX
# 55           knife  34.0      M    W             Draper    UT
# 56             gun  27.0      M    B       Indianapolis    IN
# ...            ...   ...    ...  ...                ...   ...
# 5858         knife  31.0      M    H          Fullerton    CA
# 5846           gun  35.0      M    B   Jefferson Parish    LA
# 5853           gun  53.0      M    W              Ogden    UT
# 5855       vehicle  31.0      M    W         Centennial    CO
# 5906           gun  35.0      M    B  North Little Rock    AR
# 5844         knife  22.0      F    O     Temple Terrace    FL
# 5850           gun  39.0      M    B         Snellville    GA
# 5879       vehicle  44.0      M    B              Yulee    FL
# 5863           gun  46.0      M    B           Fountain    FL
# 5878           gun  32.0      M    W          Watertown    WI
# 5866           gun  25.0      M    H          Las Vegas    NV
# 5867  undetermined  36.0      M    W       Fayetteville    AR
# 5896        hammer  22.0      M    H            Vallejo    CA
# 5897           gun  33.0      M    B           Brooklyn    NY
# 5898         knife  39.0      F    W             Poteau    OK
# 5902           gun  44.0      M    W              Aiken    SC
# 5904           gun  25.0      M    H     Corpus Christi    TX
# 5905  undetermined  36.0      M    W          Alexander    AR
# 5903           gun  42.0      M    W            Mustang    OK
# 5899           gun  24.0      M    B       New Rochelle    NY
# 5900  undetermined  22.0      M    H            Oakland    CA
# 5908         knife  35.0      M    W           Industry    CA
# 5913           gun  28.0      M    W      DeKalb County    TN
# 5914           gun  26.0      M    W        Paso Robles    CA
# 5915  undetermined  62.0      M    B          Lancaster    CA
# 5916         Taser  27.0      M    B            Atlanta    GA
# 5925           gun  23.0      M    B        Crown Point    IN
# 5918       unarmed  25.0      F    W            Sedalia    MO
# 5921           gun  22.0      M    W        Kansas City    MO
# 5924           gun  31.0      M    W           Lawrence    KS
#
#       signs_of_mental_illness  threat_level         flee  body_camera  month  \
# id
# 3                        True        attack  Not fleeing        False      1
# 4                       False        attack  Not fleeing        False      1
# 5                       False         other  Not fleeing        False      1
# 8                        True        attack  Not fleeing        False      1
# 9                       False        attack  Not fleeing        False      1
# 11                      False        attack  Not fleeing        False      1
# 13                      False        attack          Car        False      1
# 15                      False        attack  Not fleeing        False      1
# 16                      False         other  Not fleeing         True      1
# 17                      False        attack  Not fleeing        False      1
# 19                      False        attack  Not fleeing        False      1
# 21                      False        attack  Not fleeing        False      1
# 22                       True         other  Not fleeing        False      1
# 25                      False        attack          Car        False      1
# 27                      False        attack         Foot         True      1
# 32                      False        attack  Not fleeing         True      1
# 36                      False        attack  Not fleeing        False      1
# 37                      False        attack  Not fleeing         True      1
# 38                      False        attack  Not fleeing        False      1
# 325                     False        attack  Not fleeing        False      1
# 42                       True        attack  Not fleeing        False      1
# 43                      False        attack  Not fleeing        False      1
# 45                      False        attack         Foot        False      1
# 46                      False        attack         Foot         True      1
# 48                       True         other  Not fleeing        False      1
# 51                       True        attack  Not fleeing        False      1
# 52                      False        attack  Not fleeing        False      1
# 54                      False        attack  Not fleeing        False      1
# 55                      False        attack  Not fleeing         True      1
# 56                      False        attack         Foot        False      1
# ...                       ...           ...          ...          ...    ...
# 5858                    False        attack  Not fleeing        False      5
# 5846                    False        attack        Other         True      5
# 5853                    False        attack  Not fleeing        False      5
# 5855                    False        attack          Car        False      5
# 5906                    False         other  Not fleeing        False      5
# 5844                     True        attack  Not fleeing        False      5
# 5850                    False        attack          Car        False      5
# 5879                    False        attack          Car        False      5
# 5863                    False        attack  Not fleeing        False      5
# 5878                    False        attack  Not fleeing        False      5
# 5866                    False        attack  Not fleeing        False      6
# 5867                    False  undetermined  Not fleeing        False      6
# 5896                    False         other  Not fleeing        False      6
# 5897                    False         other  Not fleeing         True      6
# 5898                    False         other  Not fleeing        False      6
# 5902                    False        attack  Not fleeing        False      6
# 5904                    False        attack  Not fleeing        False      6
# 5905                    False  undetermined  Not fleeing        False      6
# 5903                    False        attack  Not fleeing        False      6
# 5899                    False        attack         Foot        False      6
# 5900                    False  undetermined  Not fleeing        False      6
# 5908                     True         other  Not fleeing        False      6
# 5913                    False         other        Other        False      6
# 5914                     True        attack         Foot        False      6
# 5915                    False  undetermined  Not fleeing        False      6
# 5916                    False        attack         Foot         True      6
# 5925                    False        attack          Car        False      6
# 5918                    False         other  Not fleeing        False      6
# 5921                    False         other        Other        False      6
# 5924                    False        attack          Car        False      6
#
#       year  day
# id
# 3     2015    2
# 4     2015    2
# 5     2015    3
# 8     2015    4
# 9     2015    4
# 11    2015    4
# 13    2015    5
# 15    2015    6
# 16    2015    6
# 17    2015    6
# 19    2015    6
# 21    2015    7
# 22    2015    7
# 25    2015    7
# 27    2015    7
# 32    2015    8
# 36    2015    8
# 37    2015    8
# 38    2015    9
# 325   2015    9
# 42    2015   11
# 43    2015   11
# 45    2015   11
# 46    2015   13
# 48    2015   13
# 51    2015   14
# 52    2015   14
# 54    2015   14
# 55    2015   14
# 56    2015   15
# ...    ...  ...
# 5858  2020   27
# 5846  2020   27
# 5853  2020   28
# 5855  2020   28
# 5906  2020   28
# 5844  2020   29
# 5850  2020   29
# 5879  2020   29
# 5863  2020   30
# 5878  2020   31
# 5866  2020    1
# 5867  2020    1
# 5896  2020    2
# 5897  2020    2
# 5898  2020    3
# 5902  2020    3
# 5904  2020    3
# 5905  2020    3
# 5903  2020    5
# 5899  2020    6
# 5900  2020    6
# 5908  2020    7
# 5913  2020   11
# 5914  2020   11
# 5915  2020   11
# 5916  2020   12
# 5925  2020   12
# 5918  2020   13
# 5921  2020   13
# 5924  2020   15
#
# [4399 rows x 16 columns]
