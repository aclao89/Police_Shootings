# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 
import missingno as msno
import plotly.express as px
import plotly.graph_objects as go
import calmap

# %% [markdown]
# # Extract Transform Load (ETL)

# %%
df = pd.read_csv('Raw_Data/datasets_723010_1257097_fatal-police-shootings-data.csv', index_col = 'id')

df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#    race           city state  signs_of_mental_illness threat_level  \
# id
# 3     A        Shelton    WA                     True       attack
# 4     W          Aloha    OR                    False       attack
# 5     H        Wichita    KS                    False        other
# 8     W  San Francisco    CA                     True       attack
# 9     H          Evans    CO                    False       attack
#
#            flee  body_camera
# id
# 3   Not fleeing        False
# 4   Not fleeing        False
# 5   Not fleeing        False
# 8   Not fleeing        False
# 9   Not fleeing        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5416 entries, 3 to 5927
# Data columns (total 13 columns):
# name                       5416 non-null object
# date                       5416 non-null object
# manner_of_death            5416 non-null object
# armed                      5189 non-null object
# age                        5181 non-null float64
# gender                     5414 non-null object
# race                       4895 non-null object
# city                       5416 non-null object
# state                      5416 non-null object
# signs_of_mental_illness    5416 non-null bool
# threat_level               5416 non-null object
# flee                       5167 non-null object
# body_camera                5416 non-null bool
# dtypes: bool(2), float64(1), object(10)
# memory usage: 518.3+ KB

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df

# Given the current climate on police brutality, it's concerning that race has the most null values. 
#This further compounds the fact law enforcement agencies are purposely hiding race to deflate 
#Since each column with null values is less than 10% then we can continue with dropping those rows since it wont impact the analysis too much
# Out:
#                                      column_name  percent_missing
# name                                        name         0.000000
# date                                        date         0.000000
# manner_of_death                  manner_of_death         0.000000
# armed                                      armed         4.191285
# age                                          age         4.338996
# gender                                    gender         0.036928
# race                                        race         9.619645
# city                                        city         0.000000
# state                                      state         0.000000
# signs_of_mental_illness  signs_of_mental_illness         0.000000
# threat_level                        threat_level         0.000000
# flee                                        flee         4.597489
# body_camera                          body_camera         0.000000

# %%
msno.matrix(df)

# %% [markdown]
# ### Drop all rows with NaN values

# %%
df_clean = df.dropna(how='any')

df_clean.shape
# Out:
# (4399, 13)

# %% [markdown]
# ### Check data types of each column - Time needs to be changed to Datetime

# %%
df_clean.dtypes
# Out:
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# dtype: object

# %% [markdown]
# ### Extract day, month, year out of date for more granular analysis

# %%
df_clean['date'] = pd.to_datetime(df_clean['date'])
df_clean['day'] = pd.to_datetime(df_clean['date']).dt.day
df_clean['month'] = pd.to_datetime(df_clean['date']).dt.month
df_clean['year'] = pd.to_datetime(df_clean['date']).dt.year

df_clean
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                
# 5924                    Nicholas Hirsh 2020-06-15              shot
#
#              armed   age gender race               city state  \
# id
# 3              gun  53.0      M    A            Shelton    WA
# 4              gun  47.0      M    W              Aloha    OR
# 5          unarmed  23.0      M    H            Wichita    KS
# 8       toy weapon  32.0      M    W      San Francisco    CA
# 9         nail gun  39.0      M    H              Evans    CO
# 11             gun  18.0      M    W            Guthrie    OK
# 13             gun  22.0      M    H           Chandler    AZ
# 15             gun  35.0      M    W            Assaria    KS
# 16         unarmed  34.0      F    W         Burlington    IA
# 17      toy weapon  47.0      M    B          Knoxville    PA
# 19           knife  25.0      M    W           Stockton    CA
# 21             gun  31.0      M    B           Freeport    TX
# 22           knife  41.0      M    B           Columbus    OH
# 25             gun  30.0      M    W         Des Moines    IA
# 27             gun  37.0      M    B        New Orleans    LA
# 32          shovel  42.0      M    W     Salt Lake City    UT
# 36         unarmed  36.0      M    B             Strong    AR
# 37             gun  49.0      M    W           Syracuse    UT
# 38             gun  71.0      M    W            England    AR
# 325            gun  33.0      M    H            El Paso    TX
# 42             gun  39.0      M    W             Arcola    IL
# 43             gun  23.0      M    H         South Gate    CA
# 45             gun  29.0      M    H    North Las Vegas    NV
# 46             gun  34.0      M    W        Albuquerque    NM
# 48           knife  43.0      M    W         Jourdanton    TX
# 51             gun  34.0      M    B         Chesapeake    VA
# 52           knife  75.0      M    W         Old Bridge    NJ
# 54             gun  68.0      M    W       Lake Jackson    TX
# 55           knife  34.0      M    W             Draper    UT
# 56             gun  27.0      M    B       Indianapolis    IN
# ...            ...   ...    ...  ...                ...   ...
# 5858         knife  31.0      M    H          Fullerton    CA
# 5846           gun  35.0      M    B   Jefferson Parish    LA
# 5853           gun  53.0      M    W              Ogden    UT
# 5855       vehicle  31.0      M    W         Centennial    CO
# 5906           gun  35.0      M    B  North Little Rock    AR
# 5844         knife  22.0      F    O     Temple Terrace    FL
# 5850           gun  39.0      M    B         Snellville    GA
# 5879       vehicle  44.0      M    B              Yulee    FL
# 5863           gun  46.0      M    B           Fountain    FL
# 5878           gun  32.0      M    W          Watertown    WI
# 5866           gun  25.0      M    H          Las Vegas    NV
# 5867  undetermined  36.0      M    W       Fayetteville    AR
# 5896        hammer  22.0      M    H            Vallejo    CA
# 5897           gun  33.0      M    B           Brooklyn    NY
# 5898         knife  39.0      F    W             Poteau    OK
# 5902           gun  44.0      M    W              Aiken    SC
# 5904           gun  25.0      M    H     Corpus Christi    TX
# 5905  undetermined  36.0      M    W          Alexander    AR
# 5903           gun  42.0      M    W            Mustang    OK
# 5899           gun  24.0      M    B       New Rochelle    NY
# 5900  undetermined  22.0      M    H            Oakland    CA
# 5908         knife  35.0      M    W           Industry    CA
# 5913           gun  28.0      M    W      DeKalb County    TN
# 5914           gun  26.0      M    W        Paso Robles    CA
# 5915  undetermined  62.0      M    B          Lancaster    CA
# 5916         Taser  27.0      M    B            Atlanta    GA
# 5925           gun  23.0      M    B        Crown Point    IN
# 5918       unarmed  25.0      F    W            Sedalia    MO
# 5921           gun  22.0      M    W        Kansas City    MO
# 5924           gun  31.0      M    W           Lawrence    KS
#
#       signs_of_mental_illness  threat_level         flee  body_camera  day  \
# id
# 3                        True        attack  Not fleeing        False    2
# 4                       False        attack  Not fleeing        False    2
# 5                       False         other  Not fleeing        False    3
# 8                        True        attack  Not fleeing        False    4
# 9                       False        attack  Not fleeing        False    4
# 11                      False        attack  Not fleeing        False    4
# 13                      False        attack          Car        False    5
# 15                      False        attack  Not fleeing        False    6
# 16                      False         other  Not fleeing         True    6
# 17                      False        attack  Not fleeing        False    6
# 19                      False        attack  Not fleeing        False    6
# 21                      False        attack  Not fleeing        False    7
# 22                       True         other  Not fleeing        False    7
# 25                      False        attack          Car        False    7
# 27                      False        attack         Foot         True    7
# 32                      False        attack  Not fleeing         True    8
# 36                      False        attack  Not fleeing        False    8
# 37                      False        attack  Not fleeing         True    8
# 38                      False        attack  Not fleeing        False    9
# 325                     False        attack  Not fleeing        False    9
# 42                       True        attack  Not fleeing        False   11
# 43                      False        attack  Not fleeing        False   11
# 45                      False        attack         Foot        False   11
# 46                      False        attack         Foot         True   13
# 48                       True         other  Not fleeing        False   13
# 51                       True        attack  Not fleeing        False   14
# 52                      False        attack  Not fleeing        False   14
# 54                      False        attack  Not fleeing        False   14
# 55                      False        attack  Not fleeing         True   14
# 56                      False        attack         Foot        False   15
# ...                       ...           ...          ...          ...  ...
# 5858                    False        attack  Not fleeing        False   27
# 5846                    False        attack        Other         True   27
# 5853                    False        attack  Not fleeing        False   28
# 5855                    False        attack          Car        False   28
# 5906                    False         other  Not fleeing        False   28
# 5844                     True        attack  Not fleeing        False   29
# 5850                    False        attack          Car        False   29
# 5879                    False        attack          Car        False   29
# 5863                    False        attack  Not fleeing        False   30
# 5878                    False        attack  Not fleeing        False   31
# 5866                    False        attack  Not fleeing        False    1
# 5867                    False  undetermined  Not fleeing        False    1
# 5896                    False         other  Not fleeing        False    2
# 5897                    False         other  Not fleeing         True    2
# 5898                    False         other  Not fleeing        False    3
# 5902                    False        attack  Not fleeing        False    3
# 5904                    False        attack  Not fleeing        False    3
# 5905                    False  undetermined  Not fleeing        False    3
# 5903                    False        attack  Not fleeing        False    5
# 5899                    False        attack         Foot        False    6
# 5900                    False  undetermined  Not fleeing        False    6
# 5908                     True         other  Not fleeing        False    7
# 5913                    False         other        Other        False   11
# 5914                     True        attack         Foot        False   11
# 5915                    False  undetermined  Not fleeing        False   11
# 5916                    False        attack         Foot         True   12
# 5925                    False        attack          Car        False   12
# 5918                    False         other  Not fleeing        False   13
# 5921                    False         other        Other        False   13
# 5924                    False        attack          Car        False   15
#
#       month  year
# id
# 3         1  2015
# 4         1  2015
# 5         1  2015
# 8         1  2015
# 9         1  2015
# 11        1  2015
# 13        1  2015
# 15        1  2015
# 16        1  2015
# 17        1  2015
# 19        1  2015
# 21        1  2015
# 22        1  2015
# 25        1  2015
# 27        1  2015
# 32        1  2015
# 36        1  2015
# 37        1  2015
# 38        1  2015
# 325       1  2015
# 42        1  2015
# 43        1  2015
# 45        1  2015
# 46        1  2015
# 48        1  2015
# 51        1  2015
# 52        1  2015
# 54        1  2015
# 55        1  2015
# 56        1  2015
# ...     ...   ...
# 5858      5  2020
# 5846      5  2020
# 5853      5  2020
# 5855      5  2020
# 5906      5  2020
# 5844      5  2020
# 5850      5  2020
# 5879      5  2020
# 5863      5  2020
# 5878      5  2020
# 5866      6  2020
# 5867      6  2020
# 5896      6  2020
# 5897      6  2020
# 5898      6  2020
# 5902      6  2020
# 5904      6  2020
# 5905      6  2020
# 5903      6  2020
# 5899      6  2020
# 5900      6  2020
# 5908      6  2020
# 5913      6  2020
# 5914      6  2020
# 5915      6  2020
# 5916      6  2020
# 5925      6  2020
# 5918      6  2020
# 5921      6  2020
# 5924      6  2020
#
# [4399 rows x 16 columns]

# %% [markdown]
# ### Change the race column to more informative text

# %%
# df_clean.race.unique()
race_cat = {'A': 'Asian', 'W':'White', 'H': 'Hispanic', 'B':'Black', 'O':'Other', 'N':'Native American'}

df_clean['race'] = df_clean['race'].map(race_cat)
df_clean
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   name       date   manner_of_death  \
# id
# 3                           Tim Elliot 2015-01-02              shot
# 4                     Lewis Lee Lembke 2015-01-02              shot
# 5                   John Paul Quintero 2015-01-03  shot and Tasered
# 8                      Matthew Hoffman 2015-01-04              shot
# 9                    Michael Rodriguez 2015-01-04              shot
# 11                   Kenneth Joe Brown 2015-01-04              shot
# 13                 Kenneth Arnold Buck 2015-01-05              shot
# 15                       Brock Nichols 2015-01-06              shot
# 16                       Autumn Steele 2015-01-06              shot
# 17                     Leslie Sapp III 2015-01-06              shot
# 19                      Patrick Wetter 2015-01-06  shot and Tasered
# 21                           Ron Sneed 2015-01-07              shot
# 22      Hashim Hanif Ibn Abdul-Rasheed 2015-01-07              shot
# 25              Nicholas Ryan Brickman 2015-01-07              shot
# 27    Omarr Julian Maximillian Jackson 2015-01-07              shot
# 32                 James Dudley Barker 2015-01-08              shot
# 36                 Artago Damon Howard 2015-01-08              shot
# 37                        Thomas Hamby 2015-01-08              shot
# 38                       Jimmy Foreman 2015-01-09              shot
# 325                      Andy Martinez 2015-01-09              shot
# 42                         Tommy Smith 2015-01-11              shot
# 43                      Brian  Barbosa 2015-01-11              shot
# 45                   Salvador Figueroa 2015-01-11  shot and Tasered
# 46                 John Edward O'Keefe 2015-01-13              shot
# 48                   Richard McClendon 2015-01-13              shot
# 51                        Mario Jordan 2015-01-14              shot
# 52                    Talbot Schroeder 2015-01-14              shot
# 54                      Robert Edwards 2015-01-14              shot
# 55                  Jeffrey R. Nielson 2015-01-14              shot
# 56                        Donte Sowell 2015-01-15              shot
# ...                                ...        ...               ...
# 5858                  Hector Hernandez 2020-05-27              shot
# 5846                     Modesto Reyes 2020-05-27  shot and Tasered
# 5853             John Benedict Coleman 2020-05-28              shot
# 5855            Steven Edward Ferguson 2020-05-28              shot
# 5906                       Ruben Smith 2020-05-28              shot
# 5844             Heba Momtaz Al-Azhari 2020-05-29              shot
# 5850               Momodou Lamin Sisay 2020-05-29              shot
# 5879                   Jarvis Sullivan 2020-05-29              shot
# 5844         knife  22.0      F     Other     Temple Terrace    FL
# 5850           gun  39.0      M     Black         Snellville    GA
# 5879       vehicle  44.0      M     Black              Yulee    FL
# 5863           gun  46.0      M     Black           Fountain    FL
# 5878           gun  32.0      M     White          Watertown    WI
# 5866           gun  25.0      M  Hispanic          Las Vegas    NV
# 5867  undetermined  36.0      M     White       Fayetteville    AR
# 5896        hammer  22.0      M  Hispanic            Vallejo    CA
# 5897           gun  33.0      M     Black           Brooklyn    NY
# 5898         knife  39.0      F     White             Poteau    OK
# 5902           gun  44.0      M     White              Aiken    SC
# 5904           gun  25.0      M  Hispanic     Corpus Christi    TX
# 5905  undetermined  36.0      M     White          Alexander    AR
# 5903           gun  42.0      M     White            Mustang    OK
# 5899           gun  24.0      M     Black       New Rochelle    NY
# 5900  undetermined  22.0      M  Hispanic            Oakland    CA
# 5908         knife  35.0      M     White           Industry    CA
# 5913           gun  28.0      M     White      DeKalb County    TN
# 5914           gun  26.0      M     White        Paso Robles    CA
# 5915  undetermined  62.0      M     Black          Lancaster    CA
# 5916         Taser  27.0      M     Black            Atlanta    GA
# 5925           gun  23.0      M     Black        Crown Point    IN
# 5918       unarmed  25.0      F     White            Sedalia    MO
# 5921           gun  22.0      M     White        Kansas City    MO
# 5924           gun  31.0      M     White           Lawrence    KS
#
#       signs_of_mental_illness  threat_level         flee  body_camera  day  \
# id
# 3                        True        attack  Not fleeing        False    2
# 4                       False        attack  Not fleeing        False    2
# 5                       False         other  Not fleeing        False    3
# 8                        True        attack  Not fleeing        False    4
# 9                       False        attack  Not fleeing        False    4
# 11                      False        attack  Not fleeing        False    4
# 13                      False        attack          Car        False    5
# 15                      False        attack  Not fleeing        False    6
# 16                      False         other  Not fleeing         True    6
# 17                      False        attack  Not fleeing        False    6
# 19                      False        attack  Not fleeing        False    6
# 21                      False        attack  Not fleeing        False    7
# 22                       True         other  Not fleeing        False    7
# 25                      False        attack          Car        False    7
# 27                      False        attack         Foot         True    7
# 32                      False        attack  Not fleeing         True    8
# 36                      False        attack  Not fleeing        False    8
# 37                      False        attack  Not fleeing         True    8
# 38                      False        attack  Not fleeing        False    9
# 325                     False        attack  Not fleeing        False    9
# 42                       True        attack  Not fleeing        False   11
# 43                      False        attack  Not fleeing        False   11
# 45                      False        attack         Foot        False   11
# 46                      False        attack         Foot         True   13
# 48                       True         other  Not fleeing        False   13
# 51                       True        attack  Not fleeing        False   14
# 52                      False        attack  Not fleeing        False   14
# 54                      False        attack  Not fleeing        False   14
# 55                      False        attack  Not fleeing         True   14
# 56                      False        attack         Foot        False   15
# ...                       ...           ...          ...          ...  ...
# 5858                    False        attack  Not fleeing        False   27
# 5846                    False        attack        Other         True   27
# 5853                    False        attack  Not fleeing        False   28
# 5855                    False        attack          Car        False   28
# 5906                    False         other  Not fleeing        False   28
# 5844                     True        attack  Not fleeing        False   29
# 5850                    False        attack          Car        False   29
# 5879                    False        attack          Car        False   29
# 5863                    False        attack  Not fleeing        False   30
# 5878                    False        attack  Not fleeing        False   31
# 5866                    False        attack  Not fleeing        False    1
# 5867                    False  undetermined  Not fleeing        False    1
# 5896                    False         other  Not fleeing        False    2
# 5897                    False         other  Not fleeing         True    2
# 5898                    False         other  Not fleeing        False    3
# 5902                    False        attack  Not fleeing        False    3
# 5904                    False        attack  Not fleeing        False    3
# 5905                    False  undetermined  Not fleeing        False    3
# 5903                    False        attack  Not fleeing        False    5
# 5899                    False        attack         Foot        False    6
# 5900                    False  undetermined  Not fleeing        False    6
# 5908                     True         other  Not fleeing        False    7
# 5913                    False         other        Other        False   11
# 5914                     True        attack         Foot        False   11
# 5915                    False  undetermined  Not fleeing        False   11
# 5916                    False        attack         Foot         True   12
# 5925                    False        attack          Car        False   12
# 5918                    False         other  Not fleeing        False   13
# 5921                    False         other        Other        False   13
# 5924                    False        attack          Car        False   15
#
#       month  year
# id
# 3         1  2015
# 4         1  2015
# 5         1  2015
# 8         1  2015
# 9         1  2015
# 11        1  2015
# 13        1  2015
# 15        1  2015
# 16        1  2015
# 17        1  2015
# 19        1  2015
# 21        1  2015
# 22        1  2015
# 25        1  2015
# 27        1  2015
# 32        1  2015
# 36        1  2015
# 37        1  2015
# 38        1  2015
# 325       1  2015
# 42        1  2015
# 43        1  2015
# 45        1  2015
# 46        1  2015
# 48        1  2015
# 51        1  2015
# 52        1  2015
# 54        1  2015
# 55        1  2015
# 56        1  2015
# ...     ...   ...
# 5858      5  2020
# 5846      5  2020
# 5853      5  2020
# 5855      5  2020
# 5906      5  2020
# 5844      5  2020
# 5850      5  2020
# 5879      5  2020
# 5863      5  2020
# 5878      5  2020
# 5866      6  2020
# 5867      6  2020
# 5896      6  2020
# 5897      6  2020
# 5898      6  2020
# 5902      6  2020
# 5904      6  2020
# 5905      6  2020
# 5903      6  2020
# 5899      6  2020
# 5900      6  2020
# 5908      6  2020
# 5913      6  2020
# 5914      6  2020
# 5915      6  2020
# 5916      6  2020
# 5925      6  2020
# 5918      6  2020
# 5921      6  2020
# 5924      6  2020
#
# [4399 rows x 16 columns]

# %%
months = {1: 'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5: "May", 6: 'Jun',
          7: 'Jul', 8: 'Aug', 9: "Sept", 10: 'Oct', 11:'Nov', 12:'Dec'}
df_clean['month'] = df_clean['month'].map(months)

df_clean
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   name       date   manner_of_death  \
# id
# 3                           Tim Elliot 2015-01-02              shot
# 4                     Lewis Lee Lembke 2015-01-02              shot
# 5                   John Paul Quintero 2015-01-03  shot and Tasered
# 8                      Matthew Hoffman 2015-01-04              shot
# 9                    Michael Rodriguez 2015-01-04              shot
# 11                   Kenneth Joe Brown 2015-01-04              shot
# 13                 Kenneth Arnold Buck 2015-01-05              shot
# 15                       Brock Nichols 2015-01-06              shot
# 16                       Autumn Steele 2015-01-06              shot
# 17                     Leslie Sapp III 2015-01-06              shot
# 19                      Patrick Wetter 2015-01-06  shot and Tasered
# 21                           Ron Sneed 2015-01-07              shot
# 22      Hashim Hanif Ibn Abdul-Rasheed 2015-01-07              shot
# 25              Nicholas Ryan Brickman 2015-01-07              shot
# 27    Omarr Julian Maximillian Jackson 2015-01-07              shot
# 25             gun  30.0      M     White         Des Moines    IA
# 27             gun  37.0      M     Black        New Orleans    LA
# 32          shovel  42.0      M     White     Salt Lake City    UT
# 36         unarmed  36.0      M     Black             Strong    AR
# 37             gun  49.0      M     White           Syracuse    UT
# 38             gun  71.0      M     White            England    AR
# 325            gun  33.0      M  Hispanic            El Paso    TX
# 42             gun  39.0      M     White             Arcola    IL
# 43             gun  23.0      M  Hispanic         South Gate    CA
# 45             gun  29.0      M  Hispanic    North Las Vegas    NV
# 46             gun  34.0      M     White        Albuquerque    NM
# 48           knife  43.0      M     White         Jourdanton    TX
# 51             gun  34.0      M     Black         Chesapeake    VA
# 52           knife  75.0      M     White         Old Bridge    NJ
# 54             gun  68.0      M     White       Lake Jackson    TX
# 55           knife  34.0      M     White             Draper    UT
# 56             gun  27.0      M     Black       Indianapolis    IN
# ...            ...   ...    ...       ...                ...   ...
# 5858         knife  31.0      M  Hispanic          Fullerton    CA
# 5846           gun  35.0      M     Black   Jefferson Parish    LA
# 5853           gun  53.0      M     White              Ogden    UT
# 5855       vehicle  31.0      M     White         Centennial    CO
# 5906           gun  35.0      M     Black  North Little Rock    AR
# 5844         knife  22.0      F     Other     Temple Terrace    FL
# 5850           gun  39.0      M     Black         Snellville    GA
# 5879       vehicle  44.0      M     Black              Yulee    FL
# 5863           gun  46.0      M     Black           Fountain    FL
# 5878           gun  32.0      M     White          Watertown    WI
# 5866           gun  25.0      M  Hispanic          Las Vegas    NV
# 5867  undetermined  36.0      M     White       Fayetteville    AR
# 5896        hammer  22.0      M  Hispanic            Vallejo    CA
# 5897           gun  33.0      M     Black           Brooklyn    NY
# 5898         knife  39.0      F     White             Poteau    OK
# 5902           gun  44.0      M     White              Aiken    SC
# 5904           gun  25.0      M  Hispanic     Corpus Christi    TX
# 5905  undetermined  36.0      M     White          Alexander    AR
# 5903           gun  42.0      M     White            Mustang    OK
# 5899           gun  24.0      M     Black       New Rochelle    NY
# 5900  undetermined  22.0      M  Hispanic            Oakland    CA
# 5908         knife  35.0      M     White           Industry    CA
# 5913           gun  28.0      M     White      DeKalb County    TN
# 5914           gun  26.0      M     White        Paso Robles    CA
# 5915  undetermined  62.0      M     Black          Lancaster    CA
# 5916         Taser  27.0      M     Black            Atlanta    GA
# 5925           gun  23.0      M     Black        Crown Point    IN
# 5918       unarmed  25.0      F     White            Sedalia    MO
# 5921           gun  22.0      M     White        Kansas City    MO
# 5924           gun  31.0      M     White           Lawrence    KS
#
#       signs_of_mental_illness  threat_level         flee  body_camera  day  \
# id
# 3                        True        attack  Not fleeing        False    2
# 4                       False        attack  Not fleeing        False    2
# 5                       False         other  Not fleeing        False    3
# 8                        True        attack  Not fleeing        False    4
# 9                       False        attack  Not fleeing        False    4
# 11                      False        attack  Not fleeing        False    4
# 13                      False        attack          Car        False    5
# 15                      False        attack  Not fleeing        False    6
# 16                      False         other  Not fleeing         True    6
# 17                      False        attack  Not fleeing        False    6
# 19                      False        attack  Not fleeing        False    6
# 21                      False        attack  Not fleeing        False    7
# 22                       True         other  Not fleeing        False    7
# 25                      False        attack          Car        False    7
# 27                      False        attack         Foot         True    7
# 32                      False        attack  Not fleeing         True    8
# 36                      False        attack  Not fleeing        False    8
# 37                      False        attack  Not fleeing         True    8
# 38                      False        attack  Not fleeing        False    9
# 325                     False        attack  Not fleeing        False    9
# 42                       True        attack  Not fleeing        False   11
# 43                      False        attack  Not fleeing        False   11
# 45                      False        attack         Foot        False   11
# 46                      False        attack         Foot         True   13
# 48                       True         other  Not fleeing        False   13
# 51                       True        attack  Not fleeing        False   14
# 52                      False        attack  Not fleeing        False   14
# 54                      False        attack  Not fleeing        False   14
# 55                      False        attack  Not fleeing         True   14
# 56                      False        attack         Foot        False   15
# ...                       ...           ...          ...          ...  ...
# 5858                    False        attack  Not fleeing        False   27
# 5846                    False        attack        Other         True   27
# 5853                    False        attack  Not fleeing        False   28
# 5855                    False        attack          Car        False   28
# 5906                    False         other  Not fleeing        False   28
# 5844                     True        attack  Not fleeing        False   29
# 5850                    False        attack          Car        False   29
# 5879                    False        attack          Car        False   29
# 5863                    False        attack  Not fleeing        False   30
# 5878                    False        attack  Not fleeing        False   31
# 5866                    False        attack  Not fleeing        False    1
# 5867                    False  undetermined  Not fleeing        False    1
# 5896                    False         other  Not fleeing        False    2
# 5897                    False         other  Not fleeing         True    2
# 5898                    False         other  Not fleeing        False    3
# 5902                    False        attack  Not fleeing        False    3
# 5904                    False        attack  Not fleeing        False    3
# 5905                    False  undetermined  Not fleeing        False    3
# 5903                    False        attack  Not fleeing        False    5
# 5899                    False        attack         Foot        False    6
# 5900                    False  undetermined  Not fleeing        False    6
# 5908                     True         other  Not fleeing        False    7
# 5913                    False         other        Other        False   11
# 5914                     True        attack         Foot        False   11
# 5915                    False  undetermined  Not fleeing        False   11
# 5916                    False        attack         Foot         True   12
# 5925                    False        attack          Car        False   12
# 5918                    False         other  Not fleeing        False   13
# 5921                    False         other        Other        False   13
# 5924                    False        attack          Car        False   15
#
#      month  year
# id
# 3      Jan  2015
# 4      Jan  2015
# 5      Jan  2015
# 8      Jan  2015
# 9      Jan  2015
# 11     Jan  2015
# 13     Jan  2015
# 15     Jan  2015
# 16     Jan  2015
# 17     Jan  2015
# 19     Jan  2015
# 21     Jan  2015
# 22     Jan  2015
# 25     Jan  2015
# 27     Jan  2015
# 32     Jan  2015
# 36     Jan  2015
# 37     Jan  2015
# 38     Jan  2015
# 325    Jan  2015
# 42     Jan  2015
# 43     Jan  2015
# 45     Jan  2015
# 46     Jan  2015
# 48     Jan  2015
# 51     Jan  2015
# 52     Jan  2015
# 54     Jan  2015
# 55     Jan  2015
# 56     Jan  2015
# ...    ...   ...
# 5858   May  2020
# 5846   May  2020
# 5853   May  2020
# 5855   May  2020
# 5906   May  2020
# 5844   May  2020
# 5850   May  2020
# 5879   May  2020
# 5863   May  2020
# 5878   May  2020
# 5866   Jun  2020
# 5867   Jun  2020
# 5896   Jun  2020
# 5897   Jun  2020
# 5898   Jun  2020
# 5902   Jun  2020
# 5904   Jun  2020
# 5905   Jun  2020
# 5903   Jun  2020
# 5899   Jun  2020
# 5900   Jun  2020
# 5908   Jun  2020
# 5913   Jun  2020
# 5914   Jun  2020
# 5915   Jun  2020
# 5916   Jun  2020
# 5925   Jun  2020
# 5918   Jun  2020
# 5921   Jun  2020
# 5924   Jun  2020
#
# [4399 rows x 16 columns]

# %%
df_clean['death_count'] = 1
# Out:
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\alao8\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Data Analysis

# %%
dth_year = df_clean.year.value_counts().reset_index()
df_deaths = dth_year.rename(columns={'index' :'Year',
               'year': 'Number killed'})

df_deaths['Avg killed per day'] = ((df_deaths['Number killed']) / 365).round()

df_deaths.style.background_gradient(cmap= 'Blues')
# Out:
# <style  type="text/css" >
#     #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col0 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col1 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col0 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col1 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col0 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col1 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col0 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col1 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Number killed</th>        <th class="col_heading level0 col2" >Avg killed per day</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col0" class="data row0 col0" >2015</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col1" class="data row0 col1" >895</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col0" class="data row1 col0" >2016</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col1" class="data row1 col1" >820</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col0" class="data row2 col0" >2018</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col1" class="data row2 col1" >800</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow2_col2" class="data row2 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col0" class="data row3 col0" >2017</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col1" class="data row3 col1" >784</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow3_col2" class="data row3 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col0" class="data row4 col0" >2019</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col1" class="data row4 col1" >764</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow4_col2" class="data row4 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col0" class="data row5 col0" >2020</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col1" class="data row5 col1" >336</td>
#                         <td id="T_8462a9cc_c3e4_11ea_aae9_802bf98fb16arow5_col2" class="data row5 col2" >1</td>
#             </tr>
#     </tbody></table>

# %%
month_deaths = df_clean['month'].value_counts().reset_index()

month_df = month_deaths.rename(columns={'index' :'Month',
               'month': 'Number killed'})
month_df 

plt.figure(figsize=(8,6))

sns.set_style("darkgrid")
sns.barplot(x = "Month", y = "Number killed", data=month_df,palette="Blues_d")

# %% [markdown]
# January seem to have the most amount of fatal police shootings. On the contary, the holiday season months, December and November, have the least.

# %%
sub_2015 = df_clean[df_clean['year'] == 2015]
sub_2016 = df_clean[df_clean['year'] == 2016]
sub_2017 = df_clean[df_clean['year'] == 2017]
sub_2018 = df_clean[df_clean['year'] == 2018]
sub_2019 = df_clean[df_clean['year'] == 2019]
sub_2020 = df_clean[df_clean['year'] == 2020]

df_2015 = sub_2015['month'].value_counts().reset_index().rename(columns={'index':'Month',
                                                              'month':'Number Killed'})
df_2016 = sub_2016['month'].value_counts().reset_index().rename(columns={'index':'Month',
                                                              'month':'Number Killed'})
df_2017 = sub_2017['month'].value_counts().reset_index().rename(columns={'index':'Month',
                                                              'month':'Number Killed'})
df_2018 = sub_2018['month'].value_counts().reset_index().rename(columns={'index':'Month',
                                                              'month':'Number Killed'})
df_2019 = sub_2019['month'].value_counts().reset_index().rename(columns={'index':'Month',
                                                              'month':'Number Killed'})
df_2020 = sub_2020['month'].value_counts().reset_index().rename(columns={'index':'Month', 
                                                                         'month':'Number Killed'})


fig, axes = plt.subplots(2, 3,figsize=(20,10))
# fig.suptitle("Sharing Year as X")
df_2015.plot(ax=axes[0,0], title='2015')
df_2016.plot(ax=axes[0,1], title='2016')
df_2017.plot(ax=axes[0,2], title='2017')
df_2018.plot(ax=axes[1,0], title='2018')
df_2019.plot(ax=axes[1,1], title='2019')
df_2020.plot(ax=axes[1,2], title='2020')

# %%
fig = plt.figure(figsize=(20,10))

calmap.yearplot(df_clean.groupby(['date'])['death_count'].sum().diff(), 
                 fillcolor='white', cmap='Reds', linewidth=0.3, year=2020)
# plt.title('Daily Confirmed Cases', fontsize=18)

# %%
year = df_clean.groupby(['year', 'month'])['death_count'].sum().reset_index()

year_df = year.reset_index()
year.sort_values(by=['death_count','year'], ascending=True)

plt.figure(figsize=(20,10))
sns.barplot(x='month', y='death_count', hue='year',data=year_df)
plt.legend(loc='upper right')

# %%
df_clean.manner_of_death.value_counts()/len(df_clean)
# Out:
# shot                0.947715
# shot and Tasered    0.052285
# Name: manner_of_death, dtype: float64

# %% [markdown]
#  According to this [policy](https://www.aclu.org/sites/default/files/field_document/30099-30102%20Taser%20policy.pdf), the primary purpose for employing the Taser is to protect human lives and prevent injury to officers and citizens. Since it's less lethal, we can assume that a taser was deployed as a first sign of warning toward the aggressor. Only 5% of cases had a taser deployed then subsequently shot. On the contrary, 95% of cases were just shot.

# %%
blacks = df_clean[df_clean['race'] == 'Black']
whites = df_clean[df_clean['race'] == 'White']
asians = df_clean[df_clean['race'] == 'Asian']
hispanics = df_clean[df_clean['race'] == 'Hispanic']
nativeamer = df_clean[df_clean['race'] == 'Native American']
o = df_clean[df_clean['race'] == 'Other']



b= blacks['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})
a=asians['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})
w=whites['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})
h=hispanics['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})
na= nativeamer['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})

other= o['armed'].value_counts().reset_index()[:5].rename(columns={'index':'Weapon in possession',
                                                                'armed': 'Count'})



fig, axes = plt.subplots(2, 3,figsize=(20,10))

b.plot(ax=axes[0,0], title='Black', kind='bar', x='Weapon in possession', y='Count', rot=0)
a.plot(ax=axes[0,1], title='Asian', kind='bar', x='Weapon in possession', y='Count', rot=0)
w.plot(ax=axes[0,2], title='White', kind='bar', x='Weapon in possession', y='Count', rot=0)
h.plot(ax=axes[1,0], title='H', kind='bar', x='Weapon in possession', y='Count', rot=0)
na.plot(ax=axes[1,1], title='Native American', kind='bar', x='Weapon in possession', y='Count', rot=0)
other.plot(ax=axes[1,2], title='Other', kind='bar', x='Weapon in possession', y='Count', rot=0)
